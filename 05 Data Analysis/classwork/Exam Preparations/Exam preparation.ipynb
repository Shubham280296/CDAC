# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1

# %%
df = pd.read_csv("movies.csv")
df.head(5)
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df1 = df[["title","budget_musd","revenue_musd","production_companies","runtime","cast_size"]]
df1 = df1.dropna()
df1[["title","budget_musd","runtime"]].head(20)
# Out:
#                              title  budget_musd  runtime
# 0                        Toy Story        30.00     81.0
# 1                          Jumanji        65.00    104.0
# 3                Waiting to Exhale        16.00    127.0
# 5                             Heat        60.00    170.0
# 8                     Sudden Death        35.00    106.0
# 9                        GoldenEye        58.00    130.0
# 10          The American President        62.00    106.0
# 13                           Nixon        44.00    192.0
# 14                Cutthroat Island        98.00    119.0
# 15                          Casino        52.00    178.0
# 16           Sense and Sensibility        16.50    136.0
# 17                      Four Rooms         4.00     98.0
# 18  Ace Ventura: When Nature Calls        30.00     90.0
# 19                     Money Train        60.00    103.0
# 20                      Get Shorty        30.25    105.0
# ...

# %%
#Q2

# %%
median = df["vote_average"].median()
df["vote_average"]= df["vote_average"].fillna(median)
first_quartile = df["vote_average"].quantile(0.25)
third_quartile = df["vote_average"].quantile(0.75)
sd = df["vote_average"].std()
outlier = df[(df["vote_average"]<(first_quartile-1.5*sd)) | (df["vote_average"]>(third_quartile+1.5*sd))]
outlier
# Out:
#            id                               title  \
# 55     124057             Kids of the Round Table
# 65      11525  Lawnmower Man 2: Beyond Cyberspace
# 100     47475                           Mr. Wrong
# 186     58372                            Reckless
# 221     61813                           Dream Man
# ...       ...                                 ...
# 44623  149946                          Two in One
# 44648   63898                             Antidur
# 44656  222872                        Starquest II
# 44661   63266                  Phobos. Fear Kills
# 44687  111109                 Century of Birthing
#
#                                                  tagline release_date  \
# 55                                                   NaN   1997-07-08
# 65     God made him simple. Science made him a god. N...   1996-01-12
# 100                                                  NaN   1996-02-16
# 186                     The most twisted Christmas ever.   1995-11-17
# ...

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='vote_average',data=df,medianprops=dict(color='red'))
# Out:
# <Axes: xlabel='vote_average'>

# %%
#Q3

# %%
df[df.isna().sum().idxmax()].fillna(df['cast_size'].mean(),inplace=True)
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
#Q4

# %%
df2 = df[(df['spoken_languages']=='English')&(df['crew_size']>df['cast_size'])]
df2['runtime'].mean()
# Out:
# 93.524015577672
