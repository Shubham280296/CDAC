# %%
from nltk import pos_tag, RegexpParser
from nltk.tokenize import word_tokenize

# %%
sent = 'The Moroccan fairy tale ends at the hands of France.'

# %%
tokens = word_tokenize(sent)
tags = pos_tag(tokens)
tags
# Out:
# [('The', 'DT'),
#  ('Moroccan', 'NNP'),
#  ('fairy', 'NN'),
#  ('tale', 'NN'),
#  ('ends', 'VBZ'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('hands', 'NNS'),
#  ('of', 'IN'),
#  ('France', 'NNP'),
#  ('.', '.')]

# %%
chunker = RegexpParser("""
NP : {<DT><NNP>}
P : {}
V : {}
PP : {<NP><NN>}
Vp : {<NN><VBZ>}
""")
result = chunker.parse(tags)
result
# Out:
# Tree('S', [Tree('PP', [Tree('NP', [('The', 'DT'), ('Moroccan', 'NNP')]), ('fairy', 'NN')]), Tree('Vp', [('tale', 'NN'), ('ends', 'VBZ')]), ('at', 'IN'), ('the', 'DT'), ('hands', 'NNS'), ('of', 'IN'), ('France', 'NNP'), ('.', '.')])

# %%
# result.draw()

# %%
print(result)
# Out:
# (S
#   (PP (NP The/DT Moroccan/NNP) fairy/NN)
#   (Vp tale/NN ends/VBZ)
#   at/IN
#   the/DT
#   hands/NNS
#   of/IN
#   France/NNP
#   ./.)

# %% [markdown]
# ## Dependancy tree

# %%
sent = 'It waws the biggest mistake made by him in the history.'

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Creating DOC object
doc = nlp(sent)

## Getting the dependecy tags
for token in doc:
    print(token.text, '-->', token.dep_)
# Out:
# It --> nsubj
# waws --> ROOT
# the --> det
# biggest --> amod
# mistake --> dobj
# made --> acl
# by --> agent
# him --> pobj
# in --> prep
# the --> det
# history --> pobj
# . --> punct

# %% [markdown]
# ## Visualizing dependency tree

# %%
from spacy import displacy

# %%
displacy.render(doc, jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="12657d8a8df84f2c92071610c43b4201-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">waws</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
sent = 'You are the biggest moron in the world I have ever seen.'
# Creating DOC object
doc = nlp(sent)

## Getting the dependecy tags
for token in doc:
    print(token.text, '-->', token.dep_)

displacy.render(doc, jupyter = True)
# Out:
# You --> nsubj
# are --> ROOT
# the --> det
# biggest --> amod
# moron --> attr
# in --> prep
# the --> det
# world --> pobj
# I --> nsubj
# have --> aux
# ever --> advmod
# seen --> relcl
# . --> punct
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e49e70bec84d4bbfa56493af62fd61c3-0" class="displacy" width="2150" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">You</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">are</tspan>
# ...

# %%
sent = 'Are you nuts?'
# Creating DOC object
doc = nlp(sent)

## Getting the dependecy tags
for token in doc:
    print(token.text, '-->', token.dep_)

displacy.render(doc, jupyter = True)
# Out:
# Are --> ROOT
# you --> nsubj
# nuts --> acomp
# ? --> punct
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c29fae3385a94c38b7dad9b7b8ac42b8-0" class="displacy" width="575" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
sent = 'Because the main character goes missing, all other characters joined hands together and overcame the hardship which was not possible for a single person alone as they had previously thought and hence they gained confidence to face any problem that may arise in the future.'
# Creating DOC object
doc = nlp(sent)

## Getting the dependecy tags
for token in doc:
    print(token.text, '-->', token.dep_)

displacy.render(doc, jupyter = True)
# Out:
# Because --> mark
# the --> det
# main --> amod
# character --> nsubj
# goes --> advcl
# missing --> acomp
# , --> punct
# all --> det
# other --> amod
# characters --> nsubj
# joined --> ROOT
# hands --> dobj
# together --> advmod
# and --> cc
# overcame --> conj
# the --> det
# hardship --> dobj
# which --> nsubj
# was --> relcl
# not --> neg
# possible --> acomp
# for --> prep
# a --> det
# single --> amod
# person --> pobj
# alone --> amod
# as --> mark
# they --> nsubj
# had --> aux
# previously --> advmod
# thought --> advcl
# and --> cc
# hence --> advmod
# they --> nsubj
# gained --> conj
# confidence --> dobj
# to --> aux
# face --> acl
# any --> det
# problem --> dobj
# that --> nsubj
# may --> aux
# arise --> relcl
# in --> prep
# the --> det
# future --> pobj
# . --> punct
# ...

# %%
.
