# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Working with Tensorflow

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../..\Classwork/input'
outDir = './output'
modelDir = './models'
subDir = 'fifa_2019'


RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate
BATCH_SIZE = 32
TEST_SIZE = 0.2

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,15),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %%
### Settings so that Tensorflow can not Hog all the GPU memory
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ['Position', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

data_df = data_df[rel_cols]
data_df.head()
# Out:
#   Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0       RF       95.0             70.0          90.0     86.0       97.0
# 1       ST       94.0             89.0          81.0     87.0       88.0
# 2       LW       87.0             62.0          84.0     84.0       96.0
# 3       GK       13.0             21.0          50.0     13.0       18.0
# 4      RCM       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
# Are there NaNs Still?
data_df.isna().sum()
# Out:
# Position           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

class_labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
y = data_df["Position"].to_numpy()

X = data_df.drop("Position", axis = 1)

#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14517, 33) (14517,) (3630, 33) (3630,)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
k_init = tf.keras.initializers.HeUniform(seed = RANDOM_STATE)

## 33/23/12/4/4
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape = (33,)),
    tf.keras.layers.Dense(33, activation = 'relu', kernel_initializer = k_init),
    #tf.keras.layers.ReLU()
    tf.keras.layers.Dense(23, activation = 'relu', kernel_initializer = k_init),
    tf.keras.layers.Dense(12, activation = 'relu', kernel_initializer = k_init),
    tf.keras.layers.Dense(4, activation = 'relu', kernel_initializer = k_init),
    tf.keras.layers.Dense(4)    
])
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.5541722 ,  0.09864296,  0.03215825, -0.35168022]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer =optimizer, loss = loss_fn, metrics = ['accuracy'])

history = model.fit(X_train, y_train, validation_data=(X_test,y_test) ,batch_size = BATCH_SIZE, epochs = EPOCHS, verbose=2)
# Out:
# Epoch 1/101
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 454/454 - 3s - loss: 0.7654 - accuracy: 0.6923 - val_loss: 0.4885 - val_accuracy: 0.8452 - 3s/epoch - 7ms/step
# Epoch 2/101
# 454/454 - 1s - loss: 0.4387 - accuracy: 0.8571 - val_loss: 0.4042 - val_accuracy: 0.8595 - 1s/epoch - 3ms/step
# Epoch 3/101
# 454/454 - 1s - loss: 0.3769 - accuracy: 0.8674 - val_loss: 0.3634 - val_accuracy: 0.8700 - 1s/epoch - 3ms/step
# Epoch 4/101
# 454/454 - 1s - loss: 0.3442 - accuracy: 0.8706 - val_loss: 0.3428 - val_accuracy: 0.8733 - 1s/epoch - 3ms/step
# Epoch 5/101
# 454/454 - 1s - loss: 0.3250 - accuracy: 0.8749 - val_loss: 0.3365 - val_accuracy: 0.8579 - 1s/epoch - 3ms/step
# Epoch 6/101
# 454/454 - 1s - loss: 0.3130 - accuracy: 0.8761 - val_loss: 0.3250 - val_accuracy: 0.8686 - 1s/epoch - 3ms/step
# Epoch 7/101
# 454/454 - 1s - loss: 0.3047 - accuracy: 0.8771 - val_loss: 0.3299 - val_accuracy: 0.8609 - 1s/epoch - 3ms/step
# Epoch 8/101
# 454/454 - 1s - loss: 0.2987 - accuracy: 0.8785 - val_loss: 0.3288 - val_accuracy: 0.8700 - 1s/epoch - 3ms/step
# Epoch 9/101
# 454/454 - 1s - loss: 0.2937 - accuracy: 0.8812 - val_loss: 0.3162 - val_accuracy: 0.8672 - 1s/epoch - 3ms/step
# Epoch 10/101
# 454/454 - 1s - loss: 0.2893 - accuracy: 0.8836 - val_loss: 0.3145 - val_accuracy: 0.8719 - 1s/epoch - 3ms/step
# Epoch 11/101
# 454/454 - 1s - loss: 0.2866 - accuracy: 0.8813 - val_loss: 0.3138 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 12/101
# 454/454 - 1s - loss: 0.2825 - accuracy: 0.8821 - val_loss: 0.3114 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 13/101
# 454/454 - 1s - loss: 0.2793 - accuracy: 0.8846 - val_loss: 0.3062 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 14/101
# 454/454 - 1s - loss: 0.2766 - accuracy: 0.8854 - val_loss: 0.3064 - val_accuracy: 0.8766 - 1s/epoch - 3ms/step
# Epoch 15/101
# 454/454 - 1s - loss: 0.2748 - accuracy: 0.8864 - val_loss: 0.3119 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 16/101
# 454/454 - 1s - loss: 0.2736 - accuracy: 0.8867 - val_loss: 0.3125 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 17/101
# 454/454 - 1s - loss: 0.2702 - accuracy: 0.8872 - val_loss: 0.3156 - val_accuracy: 0.8697 - 1s/epoch - 3ms/step
# Epoch 18/101
# 454/454 - 1s - loss: 0.2685 - accuracy: 0.8883 - val_loss: 0.3060 - val_accuracy: 0.8711 - 1s/epoch - 3ms/step
# Epoch 19/101
# 454/454 - 1s - loss: 0.2656 - accuracy: 0.8899 - val_loss: 0.3067 - val_accuracy: 0.8755 - 1s/epoch - 3ms/step
# Epoch 20/101
# 454/454 - 1s - loss: 0.2634 - accuracy: 0.8922 - val_loss: 0.3101 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 21/101
# 454/454 - 1s - loss: 0.2623 - accuracy: 0.8907 - val_loss: 0.3067 - val_accuracy: 0.8766 - 1s/epoch - 3ms/step
# Epoch 22/101
# 454/454 - 1s - loss: 0.2612 - accuracy: 0.8924 - val_loss: 0.3081 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 23/101
# 454/454 - 1s - loss: 0.2586 - accuracy: 0.8913 - val_loss: 0.3139 - val_accuracy: 0.8650 - 1s/epoch - 3ms/step
# Epoch 24/101
# 454/454 - 1s - loss: 0.2584 - accuracy: 0.8936 - val_loss: 0.3065 - val_accuracy: 0.8771 - 1s/epoch - 3ms/step
# Epoch 25/101
# 454/454 - 1s - loss: 0.2583 - accuracy: 0.8911 - val_loss: 0.3090 - val_accuracy: 0.8722 - 1s/epoch - 3ms/step
# Epoch 26/101
# 454/454 - 1s - loss: 0.2558 - accuracy: 0.8938 - val_loss: 0.3090 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 27/101
# 454/454 - 1s - loss: 0.2553 - accuracy: 0.8936 - val_loss: 0.3098 - val_accuracy: 0.8747 - 1s/epoch - 3ms/step
# Epoch 28/101
# 454/454 - 1s - loss: 0.2528 - accuracy: 0.8958 - val_loss: 0.3112 - val_accuracy: 0.8738 - 1s/epoch - 3ms/step
# Epoch 29/101
# 454/454 - 1s - loss: 0.2512 - accuracy: 0.8955 - val_loss: 0.3153 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 30/101
# 454/454 - 1s - loss: 0.2510 - accuracy: 0.8963 - val_loss: 0.3073 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 31/101
# 454/454 - 1s - loss: 0.2497 - accuracy: 0.8974 - val_loss: 0.3184 - val_accuracy: 0.8708 - 1s/epoch - 3ms/step
# Epoch 32/101
# 454/454 - 1s - loss: 0.2478 - accuracy: 0.8976 - val_loss: 0.3141 - val_accuracy: 0.8747 - 1s/epoch - 3ms/step
# Epoch 33/101
# 454/454 - 1s - loss: 0.2469 - accuracy: 0.8963 - val_loss: 0.3388 - val_accuracy: 0.8609 - 1s/epoch - 3ms/step
# Epoch 34/101
# 454/454 - 1s - loss: 0.2468 - accuracy: 0.8970 - val_loss: 0.3180 - val_accuracy: 0.8694 - 1s/epoch - 3ms/step
# Epoch 35/101
# 454/454 - 1s - loss: 0.2450 - accuracy: 0.8978 - val_loss: 0.3232 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 36/101
# 454/454 - 1s - loss: 0.2434 - accuracy: 0.8994 - val_loss: 0.3226 - val_accuracy: 0.8713 - 1s/epoch - 3ms/step
# Epoch 37/101
# 454/454 - 1s - loss: 0.2435 - accuracy: 0.8978 - val_loss: 0.3218 - val_accuracy: 0.8686 - 1s/epoch - 3ms/step
# Epoch 38/101
# 454/454 - 1s - loss: 0.2410 - accuracy: 0.9011 - val_loss: 0.3300 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 39/101
# 454/454 - 1s - loss: 0.2398 - accuracy: 0.9014 - val_loss: 0.3312 - val_accuracy: 0.8691 - 1s/epoch - 3ms/step
# Epoch 40/101
# 454/454 - 1s - loss: 0.2394 - accuracy: 0.9009 - val_loss: 0.3250 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 41/101
# 454/454 - 1s - loss: 0.2396 - accuracy: 0.9013 - val_loss: 0.3246 - val_accuracy: 0.8664 - 1s/epoch - 3ms/step
# Epoch 42/101
# 454/454 - 1s - loss: 0.2376 - accuracy: 0.9006 - val_loss: 0.3309 - val_accuracy: 0.8658 - 1s/epoch - 3ms/step
# Epoch 43/101
# 454/454 - 1s - loss: 0.2363 - accuracy: 0.9016 - val_loss: 0.3310 - val_accuracy: 0.8689 - 1s/epoch - 3ms/step
# Epoch 44/101
# 454/454 - 1s - loss: 0.2366 - accuracy: 0.9014 - val_loss: 0.3389 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 45/101
# 454/454 - 1s - loss: 0.2357 - accuracy: 0.9019 - val_loss: 0.3317 - val_accuracy: 0.8686 - 1s/epoch - 3ms/step
# Epoch 46/101
# 454/454 - 1s - loss: 0.2351 - accuracy: 0.9038 - val_loss: 0.3347 - val_accuracy: 0.8672 - 1s/epoch - 3ms/step
# Epoch 47/101
# 454/454 - 1s - loss: 0.2337 - accuracy: 0.9022 - val_loss: 0.3292 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 48/101
# 454/454 - 1s - loss: 0.2325 - accuracy: 0.9047 - val_loss: 0.3397 - val_accuracy: 0.8634 - 1s/epoch - 3ms/step
# Epoch 49/101
# 454/454 - 1s - loss: 0.2326 - accuracy: 0.9039 - val_loss: 0.3362 - val_accuracy: 0.8650 - 1s/epoch - 3ms/step
# Epoch 50/101
# 454/454 - 1s - loss: 0.2318 - accuracy: 0.9047 - val_loss: 0.3388 - val_accuracy: 0.8631 - 1s/epoch - 3ms/step
# Epoch 51/101
# 454/454 - 1s - loss: 0.2312 - accuracy: 0.9025 - val_loss: 0.3338 - val_accuracy: 0.8636 - 1s/epoch - 3ms/step
# Epoch 52/101
# 454/454 - 1s - loss: 0.2306 - accuracy: 0.9043 - val_loss: 0.3397 - val_accuracy: 0.8675 - 1s/epoch - 3ms/step
# Epoch 53/101
# 454/454 - 1s - loss: 0.2291 - accuracy: 0.9055 - val_loss: 0.3373 - val_accuracy: 0.8678 - 1s/epoch - 3ms/step
# Epoch 54/101
# 454/454 - 1s - loss: 0.2270 - accuracy: 0.9070 - val_loss: 0.3378 - val_accuracy: 0.8656 - 1s/epoch - 3ms/step
# Epoch 55/101
# 454/454 - 1s - loss: 0.2268 - accuracy: 0.9070 - val_loss: 0.3515 - val_accuracy: 0.8625 - 1s/epoch - 3ms/step
# Epoch 56/101
# 454/454 - 1s - loss: 0.2273 - accuracy: 0.9057 - val_loss: 0.3470 - val_accuracy: 0.8697 - 1s/epoch - 3ms/step
# Epoch 57/101
# 454/454 - 1s - loss: 0.2263 - accuracy: 0.9078 - val_loss: 0.3491 - val_accuracy: 0.8631 - 1s/epoch - 3ms/step
# Epoch 58/101
# 454/454 - 1s - loss: 0.2265 - accuracy: 0.9045 - val_loss: 0.3540 - val_accuracy: 0.8614 - 1s/epoch - 3ms/step
# Epoch 59/101
# 454/454 - 1s - loss: 0.2258 - accuracy: 0.9048 - val_loss: 0.3506 - val_accuracy: 0.8634 - 1s/epoch - 3ms/step
# Epoch 60/101
# 454/454 - 1s - loss: 0.2238 - accuracy: 0.9066 - val_loss: 0.3490 - val_accuracy: 0.8639 - 1s/epoch - 3ms/step
# Epoch 61/101
# 454/454 - 1s - loss: 0.2238 - accuracy: 0.9085 - val_loss: 0.3545 - val_accuracy: 0.8617 - 1s/epoch - 3ms/step
# Epoch 62/101
# 454/454 - 1s - loss: 0.2221 - accuracy: 0.9054 - val_loss: 0.3539 - val_accuracy: 0.8606 - 1s/epoch - 3ms/step
# Epoch 63/101
# 454/454 - 1s - loss: 0.2228 - accuracy: 0.9062 - val_loss: 0.3512 - val_accuracy: 0.8620 - 1s/epoch - 3ms/step
# Epoch 64/101
# 454/454 - 1s - loss: 0.2213 - accuracy: 0.9089 - val_loss: 0.3499 - val_accuracy: 0.8661 - 1s/epoch - 3ms/step
# Epoch 65/101
# 454/454 - 1s - loss: 0.2200 - accuracy: 0.9074 - val_loss: 0.3536 - val_accuracy: 0.8642 - 1s/epoch - 3ms/step
# Epoch 66/101
# 454/454 - 1s - loss: 0.2187 - accuracy: 0.9093 - val_loss: 0.3529 - val_accuracy: 0.8623 - 1s/epoch - 3ms/step
# Epoch 67/101
# 454/454 - 1s - loss: 0.2188 - accuracy: 0.9096 - val_loss: 0.3648 - val_accuracy: 0.8573 - 1s/epoch - 3ms/step
# Epoch 68/101
# 454/454 - 1s - loss: 0.2187 - accuracy: 0.9090 - val_loss: 0.3675 - val_accuracy: 0.8595 - 1s/epoch - 3ms/step
# Epoch 69/101
# 454/454 - 2s - loss: 0.2172 - accuracy: 0.9089 - val_loss: 0.3639 - val_accuracy: 0.8603 - 2s/epoch - 3ms/step
# Epoch 70/101
# 454/454 - 1s - loss: 0.2152 - accuracy: 0.9096 - val_loss: 0.3670 - val_accuracy: 0.8570 - 1s/epoch - 3ms/step
# Epoch 71/101
# 454/454 - 1s - loss: 0.2166 - accuracy: 0.9109 - val_loss: 0.3574 - val_accuracy: 0.8634 - 1s/epoch - 3ms/step
# Epoch 72/101
# 454/454 - 1s - loss: 0.2152 - accuracy: 0.9090 - val_loss: 0.3622 - val_accuracy: 0.8639 - 1s/epoch - 3ms/step
# Epoch 73/101
# 454/454 - 1s - loss: 0.2153 - accuracy: 0.9115 - val_loss: 0.3845 - val_accuracy: 0.8537 - 1s/epoch - 3ms/step
# Epoch 74/101
# 454/454 - 1s - loss: 0.2141 - accuracy: 0.9105 - val_loss: 0.3637 - val_accuracy: 0.8609 - 1s/epoch - 3ms/step
# Epoch 75/101
# 454/454 - 1s - loss: 0.2135 - accuracy: 0.9113 - val_loss: 0.3679 - val_accuracy: 0.8590 - 1s/epoch - 3ms/step
# Epoch 76/101
# 454/454 - 1s - loss: 0.2127 - accuracy: 0.9100 - val_loss: 0.3652 - val_accuracy: 0.8614 - 1s/epoch - 3ms/step
# Epoch 77/101
# 454/454 - 1s - loss: 0.2119 - accuracy: 0.9120 - val_loss: 0.3712 - val_accuracy: 0.8595 - 1s/epoch - 3ms/step
# Epoch 78/101
# 454/454 - 1s - loss: 0.2118 - accuracy: 0.9116 - val_loss: 0.3690 - val_accuracy: 0.8664 - 1s/epoch - 3ms/step
# Epoch 79/101
# 454/454 - 1s - loss: 0.2098 - accuracy: 0.9105 - val_loss: 0.3720 - val_accuracy: 0.8601 - 1s/epoch - 3ms/step
# Epoch 80/101
# 454/454 - 1s - loss: 0.2090 - accuracy: 0.9139 - val_loss: 0.3756 - val_accuracy: 0.8556 - 1s/epoch - 3ms/step
# Epoch 81/101
# 454/454 - 2s - loss: 0.2110 - accuracy: 0.9116 - val_loss: 0.3794 - val_accuracy: 0.8598 - 2s/epoch - 3ms/step
# Epoch 82/101
# 454/454 - 2s - loss: 0.2090 - accuracy: 0.9131 - val_loss: 0.3756 - val_accuracy: 0.8612 - 2s/epoch - 4ms/step
# Epoch 83/101
# 454/454 - 1s - loss: 0.2082 - accuracy: 0.9147 - val_loss: 0.3768 - val_accuracy: 0.8556 - 1s/epoch - 3ms/step
# Epoch 84/101
# 454/454 - 1s - loss: 0.2073 - accuracy: 0.9143 - val_loss: 0.3816 - val_accuracy: 0.8587 - 1s/epoch - 3ms/step
# Epoch 85/101
# 454/454 - 1s - loss: 0.2076 - accuracy: 0.9133 - val_loss: 0.3767 - val_accuracy: 0.8562 - 1s/epoch - 3ms/step
# Epoch 86/101
# 454/454 - 1s - loss: 0.2069 - accuracy: 0.9129 - val_loss: 0.3732 - val_accuracy: 0.8576 - 1s/epoch - 3ms/step
# Epoch 87/101
# 454/454 - 1s - loss: 0.2058 - accuracy: 0.9131 - val_loss: 0.3837 - val_accuracy: 0.8617 - 1s/epoch - 3ms/step
# Epoch 88/101
# 454/454 - 1s - loss: 0.2048 - accuracy: 0.9147 - val_loss: 0.3946 - val_accuracy: 0.8515 - 1s/epoch - 3ms/step
# Epoch 89/101
# 454/454 - 1s - loss: 0.2049 - accuracy: 0.9158 - val_loss: 0.3864 - val_accuracy: 0.8455 - 1s/epoch - 3ms/step
# Epoch 90/101
# 454/454 - 1s - loss: 0.2032 - accuracy: 0.9160 - val_loss: 0.3834 - val_accuracy: 0.8551 - 1s/epoch - 3ms/step
# Epoch 91/101
# 454/454 - 1s - loss: 0.2029 - accuracy: 0.9155 - val_loss: 0.3910 - val_accuracy: 0.8567 - 1s/epoch - 3ms/step
# Epoch 92/101
# 454/454 - 1s - loss: 0.2022 - accuracy: 0.9155 - val_loss: 0.3901 - val_accuracy: 0.8570 - 1s/epoch - 3ms/step
# Epoch 93/101
# 454/454 - 1s - loss: 0.2015 - accuracy: 0.9173 - val_loss: 0.4006 - val_accuracy: 0.8515 - 1s/epoch - 3ms/step
# Epoch 94/101
# 454/454 - 1s - loss: 0.2012 - accuracy: 0.9176 - val_loss: 0.3819 - val_accuracy: 0.8609 - 1s/epoch - 3ms/step
# Epoch 95/101
# 454/454 - 1s - loss: 0.2012 - accuracy: 0.9169 - val_loss: 0.3829 - val_accuracy: 0.8579 - 1s/epoch - 3ms/step
# Epoch 96/101
# 454/454 - 1s - loss: 0.2006 - accuracy: 0.9184 - val_loss: 0.3857 - val_accuracy: 0.8612 - 1s/epoch - 3ms/step
# Epoch 97/101
# 454/454 - 1s - loss: 0.1989 - accuracy: 0.9193 - val_loss: 0.3887 - val_accuracy: 0.8543 - 1s/epoch - 3ms/step
# Epoch 98/101
# 454/454 - 1s - loss: 0.1978 - accuracy: 0.9185 - val_loss: 0.4078 - val_accuracy: 0.8537 - 1s/epoch - 3ms/step
# Epoch 99/101
# 454/454 - 1s - loss: 0.1972 - accuracy: 0.9180 - val_loss: 0.3948 - val_accuracy: 0.8556 - 1s/epoch - 3ms/step
# Epoch 100/101
# 454/454 - 1s - loss: 0.1984 - accuracy: 0.9161 - val_loss: 0.3947 - val_accuracy: 0.8576 - 1s/epoch - 3ms/step
# Epoch 101/101
# 454/454 - 1s - loss: 0.1981 - accuracy: 0.9185 - val_loss: 0.3981 - val_accuracy: 0.8565 - 1s/epoch - 3ms/step

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))
