# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Simple RNN
#
#
# ## weather dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

from utils.helper import fn_plot_tf_hist
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print (fn_plot_tf_hist.__doc__)
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../..\Classwork/input'
outDir = '../output'
modelDir = '../models'
subDir = 'weather'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
tf.random.set_seed(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 20 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'medium',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'weatherHistory.csv'))
data_df.shape
# Out:
# (96453, 12)

# %%
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %% [markdown]
# ## take care of time zone

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], utc = True)
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary                  datetime
# 0  Partly cloudy throughout the day. 2006-03-31 22:00:00+00:00
# 1  Partly cloudy throughout the day. 2006-03-31 23:00:00+00:00
# 2  Partly cloudy throughout the day. 2006-04-01 00:00:00+00:00
# 3  Partly cloudy throughout the day. 2006-04-01 01:00:00+00:00
# 4  Partly cloudy throughout the day. 2006-04-01 02:00:00+00:00

# %% [markdown]
# ##  Visualization

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
#  12  datetime                  96453 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(8), object(4)
# memory usage: 9.6+ MB

# %%
data_df.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# Wind Speed (km/h)            5.828200     9.9659    14.135800    63.852600
# Wind Bearing (degrees)     116.000000   180.0000   290.000000   359.000000
# Visibility (km)              8.339800    10.0464    14.812000    16.100000
# Loud Cover                   0.000000     0.0000     0.000000     0.000000
# Pressure (millibars)      1011.900000  1016.4500  1021.090000  1046.380000

# %%
data_df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'datetime'],
#       dtype='object')

# %%
num_col = ['Temperature (C)','Apparent Temperature (C)', 'Humidity','Wind Speed (km/h)',
           'Wind Bearing (degrees)','Visibility (km)','Loud Cover','Pressure (millibars)']

# %%
fig,axes = plt.subplots(2,4)
axes = axes.ravel()
for count, col in enumerate(num_col):
    ax = axes[count]
    sns.histplot(data_df, x=col, ax=ax, bins=50)
plt.tight_layout()

# %%
fig,axes = plt.subplots(2,4)
axes = axes.ravel()
for count, col in enumerate(num_col):
    ax = axes[count]
    sns.boxplot(data_df, y=col, ax=ax)
plt.tight_layout()

# %%
data_df[num_col].corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# Wind Bearing (degrees)             0.103822                1.000000
# Visibility (km)                    0.100749                0.047594
# Loud Cover                              NaN                     NaN
# Pressure (millibars)              -0.049263               -0.011651
#
#                           Visibility (km)  Loud Cover  Pressure (millibars)
# Temperature (C)                  0.392847         NaN             -0.005447
# Apparent Temperature (C)         0.381718         NaN             -0.000219
# Humidity                        -0.369173         NaN              0.005454
# Wind Speed (km/h)                0.100749         NaN             -0.049263
# Wind Bearing (degrees)           0.047594         NaN             -0.011651
# Visibility (km)                  1.000000         NaN              0.059818
# Loud Cover                            NaN         NaN                   NaN
# Pressure (millibars)             0.059818         NaN              1.000000

# %%
sns.heatmap(data_df[num_col].corr(), annot=True, cmap='Dark2_r')
# Out:
# <Axes: >

# %%
tmp_df = data_df[['datetime','Temperature (C)',
                  'Humidity', 'Visibility (km)']]
tmp_df = tmp_df.sort_values('datetime', axis=0, ascending=True)
tmp_df = tmp_df.reset_index(drop=True)
tmp_df.head()
# Out:
#                    datetime  Temperature (C)  Humidity  Visibility (km)
# 0 2005-12-31 23:00:00+00:00         0.577778      0.89           9.9820
# 1 2006-01-01 00:00:00+00:00         1.161111      0.85           9.9015
# 2 2006-01-01 01:00:00+00:00         1.666667      0.82           9.9015
# 3 2006-01-01 02:00:00+00:00         1.711111      0.82           9.9015
# 4 2006-01-01 03:00:00+00:00         1.183333      0.86           9.9015

# %%
tmp_df = tmp_df.rename({'Temperature (C)':'temp','Humidity':'hum','Visibility (km)':'viz'},axis=1)
tmp_df.head()
# Out:
#                    datetime      temp   hum     viz
# 0 2005-12-31 23:00:00+00:00  0.577778  0.89  9.9820
# 1 2006-01-01 00:00:00+00:00  1.161111  0.85  9.9015
# 2 2006-01-01 01:00:00+00:00  1.666667  0.82  9.9015
# 3 2006-01-01 02:00:00+00:00  1.711111  0.82  9.9015
# 4 2006-01-01 03:00:00+00:00  1.183333  0.86  9.9015

# %%
fig = plt.figure(figsize=(15,4))
ax = fig.add_subplot(1,3,1)
tmp_df.plot(x= 'datetime', y='temp', style='.',ax = ax)
ax = fig.add_subplot(1,3,2)
tmp_df.plot(x= 'datetime', y='viz', style='.',ax = ax)
ax = fig.add_subplot(1,3,3)
tmp_df.plot(x= 'datetime', y='hum', style='.',ax = ax)
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# ## Data preparations
#
# ###

# %%
time_step = 24
y_index = np.arange(time_step,tmp_df.shape[0], time_step)
y_index
# Out:
# array([   24,    48,    72, ..., 96384, 96408, 96432])

# %%
y_df = tmp_df.iloc[y_index][['datetime','temp']]

X_df =tmp_df.iloc[range(len(y_df)*time_step)]  ### only taking data as training data where len/time step is whole 
                                                ### number insuring every data in X_df has ouyput y_df
    
    
X_temp = np.reshape(X_df['temp'].to_numpy(),
              (y_df.shape[0],time_step))

X_hum = np.reshape(X_df['hum'].to_numpy(),
              (y_df.shape[0],time_step))

X_viz = np.reshape(X_df['viz'].to_numpy(),
              (y_df.shape[0],time_step))

X_temp = X_temp[:,:23]
X_hum = X_hum[:,:23]
X_viz = X_viz[:,:23]

X_viz.shape
# Out:
# (4018, 23)

# %%
X_data = np.stack((X_temp,X_hum), axis=2)
X_data.shape
# Out:
# (4018, 23, 2)

# %%
# splitting in train ans test datasets
split = int(y_df.shape[0]*(1-TEST_SIZE))

X_train = X_data[:split]
X_test = X_data[split:]

y_train = y_df['temp'].to_numpy()[:split]
y_test = y_df['temp'].to_numpy()[split:]

# %% [markdown]
# ## Model

# %%
h_units=256
input_shape=(time_step-1,X_train.shape[2])

model = tf.keras.Sequential()

model.add(tf.keras.layers.SimpleRNN(units= h_units, 
                                    input_shape=input_shape,
                                    activation='tanh'))
model.add(tf.keras.layers.Dense(1, activation='linear'))

model.compile(loss = 'mean_squared_error',optimizer='adam', metrics=[tf.keras.metrics.RootMeanSquaredError()])
# Out:
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
wax = model.get_weights()[0].shape
waa = model.get_weights()[1].shape
baa = model.get_weights()[2].shape
way = model.get_weights()[3].shape
bay = model.get_weights()[4].shape

wax, waa, baa, way, bay
# Out:
# ((2, 256), (256, 256), (256,), (256, 1), (1,))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 256)               66304
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 66561 (260.00 KB)
# Trainable params: 66561 (260.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train, epochs = EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 101/101 [==============================] - 4s 22ms/step - loss: 10.9695 - root_mean_squared_error: 3.3120 - val_loss: 1.0059 - val_root_mean_squared_error: 1.0030
# Epoch 2/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.6917 - root_mean_squared_error: 1.3006 - val_loss: 0.8645 - val_root_mean_squared_error: 0.9298
# Epoch 3/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.3149 - root_mean_squared_error: 1.1467 - val_loss: 0.8203 - val_root_mean_squared_error: 0.9057
# Epoch 4/20
# 101/101 [==============================] - 2s 19ms/step - loss: 1.1947 - root_mean_squared_error: 1.0930 - val_loss: 0.8023 - val_root_mean_squared_error: 0.8957
# Epoch 5/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.1075 - root_mean_squared_error: 1.0524 - val_loss: 0.7086 - val_root_mean_squared_error: 0.8418
# Epoch 6/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.1306 - root_mean_squared_error: 1.0633 - val_loss: 0.8850 - val_root_mean_squared_error: 0.9407
# Epoch 7/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.4338 - root_mean_squared_error: 1.1974 - val_loss: 0.7927 - val_root_mean_squared_error: 0.8903
# Epoch 8/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.5080 - root_mean_squared_error: 1.2280 - val_loss: 0.8740 - val_root_mean_squared_error: 0.9349
# Epoch 9/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.1234 - root_mean_squared_error: 1.0599 - val_loss: 1.0281 - val_root_mean_squared_error: 1.0139
# Epoch 10/20
# 101/101 [==============================] - 1s 15ms/step - loss: 1.1421 - root_mean_squared_error: 1.0687 - val_loss: 0.9518 - val_root_mean_squared_error: 0.9756
# Epoch 11/20
# 101/101 [==============================] - 2s 16ms/step - loss: 1.1058 - root_mean_squared_error: 1.0516 - val_loss: 1.0740 - val_root_mean_squared_error: 1.0363
# Epoch 12/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.0983 - root_mean_squared_error: 1.0480 - val_loss: 0.6669 - val_root_mean_squared_error: 0.8167
# Epoch 13/20
# 101/101 [==============================] - 2s 19ms/step - loss: 1.0405 - root_mean_squared_error: 1.0201 - val_loss: 0.6561 - val_root_mean_squared_error: 0.8100
# Epoch 14/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.0829 - root_mean_squared_error: 1.0406 - val_loss: 0.6899 - val_root_mean_squared_error: 0.8306
# Epoch 15/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.0576 - root_mean_squared_error: 1.0284 - val_loss: 0.7018 - val_root_mean_squared_error: 0.8377
# Epoch 16/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.0521 - root_mean_squared_error: 1.0257 - val_loss: 0.6762 - val_root_mean_squared_error: 0.8223
# Epoch 17/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.0250 - root_mean_squared_error: 1.0124 - val_loss: 1.0088 - val_root_mean_squared_error: 1.0044
# Epoch 18/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.0490 - root_mean_squared_error: 1.0242 - val_loss: 0.7039 - val_root_mean_squared_error: 0.8390
# Epoch 19/20
# 101/101 [==============================] - 2s 18ms/step - loss: 1.0382 - root_mean_squared_error: 1.0189 - val_loss: 0.7293 - val_root_mean_squared_error: 0.8540
# Epoch 20/20
# 101/101 [==============================] - 2s 17ms/step - loss: 1.0556 - root_mean_squared_error: 1.0274 - val_loss: 0.8938 - val_root_mean_squared_error: 0.9454

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.append(y_train_pred,y_test_pred)
y_pred
# Out:
# 101/101 [==============================] - 1s 8ms/step
# 26/26 [==============================] - 0s 8ms/step
# array([ 4.3794637,  1.3238238,  1.4381093, ..., -1.0339798, -1.0817816,
#        -1.1239159], dtype=float32)

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#        datetime      temp      pred
# 24   2006-01-01  5.422222  4.379464
# 48   2006-01-02  1.694444  1.323824
# 72   2006-01-03  2.200000  1.438109
# 96   2006-01-04  1.666667  1.351177
# 120  2006-01-05  1.805556  1.881807

# %%
fig, ax = plt.subplots(figsize=(30,6))
res_df[-1000:].plot(x = 'datetime', y= ['temp', 'pred'], ax=ax);
