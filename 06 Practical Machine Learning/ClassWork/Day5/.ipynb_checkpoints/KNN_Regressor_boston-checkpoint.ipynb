# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score,log_loss,accuracy_score

# %%
kyp = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Cases\Kyphosis\Kyphosis.csv")
le = LabelEncoder()
y = le.fit_transform(kyp["Kyphosis"])
X = kyp.drop('Kyphosis',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=24,stratify =y)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train,y_train)

y_pred = knn.predict(X_test)
y_pred_proba = knn.predict_proba(X_test)

# %%
print(accuracy_score(y_test,y_pred))
print(roc_auc_score(y_test,y_pred))
print(log_loss(y_test,y_pred))
# Out:
# 0.84
# 0.6
# 5.7669845422587445

# %%
### KNN using gridsearch and Kfold

# %%
knn = KNeighborsClassifier()
params= {"n_neighbors":np.arange(1,11)}
kfold = StratifiedKFold(n_splits =5,shuffle = True, random_state = 24)
gcv = GridSearchCV(knn,param_grid=params, scoring="neg_log_loss",cv=kfold)

gcv.fit(X,y)

pd.DataFrame(gcv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.001394      0.001195         0.002220        0.001819
# 1       0.003805      0.005655         0.002352        0.001306
# 2       0.000998      0.000892         0.003389        0.003091
# 3       0.001593      0.000488         0.002190        0.000398
# 4       0.001708      0.000619         0.002392        0.000487
# 5       0.001194      0.000745         0.002976        0.001612
# 6       0.000000      0.000000         0.003144        0.006289
# 7       0.000000      0.000000         0.003124        0.006248
# 8       0.000000      0.000000         0.003126        0.006251
# 9       0.000000      0.000000         0.006349        0.006277
#
#   param_n_neighbors               params  split0_test_score  \
# 0                 1   {'n_neighbors': 1}          -8.480860
# 1                 2   {'n_neighbors': 2}          -6.442191
# 2                 3   {'n_neighbors': 3}          -4.488933
# 3                 4   {'n_neighbors': 4}          -4.518915
# 4                 5   {'n_neighbors': 5}          -4.529251
# 5                 6   {'n_neighbors': 6}          -2.492433
# 6                 7   {'n_neighbors': 7}          -2.512288
# 7                 8   {'n_neighbors': 8}          -2.512617
# 8                 9   {'n_neighbors': 9}          -2.504413
# 9                10  {'n_neighbors': 10}          -2.536798
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -9.010913          -9.010913         -13.516370         -13.516370
# 1          -2.512659          -2.426015          -9.140878          -6.931472
# 2          -2.574807          -0.282015          -2.628748          -2.603406
# 3          -2.537153          -0.349831          -0.523118          -2.689203
# 4          -2.513314          -0.330732          -0.519740          -2.644762
# 5          -0.377209          -0.331629          -0.435546          -2.683464
# 6          -0.393037          -0.343104          -0.427999          -2.623433
# 7          -0.366218          -0.365234          -0.397101          -2.610626
# 8          -0.419371          -0.349932          -0.442674          -2.656905
# 9          -0.439849          -0.341046          -0.465703          -2.664684
#
#    mean_test_score  std_test_score  rank_test_score
# 0       -10.707085        2.301923               10
# 1        -5.490643        2.629296                9
# 2        -2.515582        1.334688                8
# 3        -2.123644        1.545074                7
# 4        -2.107560        1.548942                6
# 5        -1.264056        1.083142                3
# 6        -1.259972        1.068805                2
# 7        -1.250359        1.071151                1
# 8        -1.274659        1.067870                4
# 9        -1.289616        1.072101                5

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'n_neighbors': 8}
# -1.2503592106282053
