# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\milk.csv", index_col=0)

# %%
clf = IsolationForest(contamination=0.05, random_state=24)
clf.fit(df)
predictions = clf.predict(df)

# %%
print("%age of outliers="+ str((predictions<0).mean()*100)+ "%")
abn_ind = np.where(predictions < 0)
print("Outliers:")
print(df.index[abn_ind])
# Out:
# %age of outliers=8.0%
# Outliers:
# Index(['SEAL', 'DOLPHIN'], dtype='object', name='Animal')

# %%
###### Visualization of Outliers ################
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
prcomp = PCA()
scores = prcomp.fit_transform(scaled_df)

print(np.cumsum(prcomp.explained_variance_ratio_))

obs = np.where(predictions == 1, "Inlier", "Outlier")
PCs = pd.DataFrame({'PC1':scores[:,0], 'PC2':scores[:,1],
                    'Class':obs})

sns.scatterplot(data=PCs, x='PC1',
                y='PC2', hue='Class')
for i in np.arange(0, df.shape[0] ):
    plt.text(scores[i,0], scores[i,1], 
             list(df.index)[i],fontsize=6)
plt.legend(loc='best')
plt.title("PCA")
plt.show()
# Out:
# [0.77575905 0.95323854 0.97902239 0.9987386  1.        ]

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\nutrient.csv", index_col=0)
df.head()
# Out:
#               energy  protein  fat  calcium  iron
# Food_Item
# BEEF BRAISED     340       20   28        9   2.6
# HAMBURGER        245       21   17        9   2.7
# BEEF ROAST       420       15   39        7   2.0
# BEEF STEAK       375       19   32        9   2.6
# BEEF CANNED      180       22   10       17   3.7

# %%
clf = IsolationForest(contamination=0.1, random_state=24)
clf.fit(df)
predictions = clf.predict(df)

print("%age of outliers="+ str((predictions<0).mean()*100)+ "%")
abn_ind = np.where(predictions < 0)
print("Outliers:")
print(df.index[abn_ind])
# Out:
# %age of outliers=11.11111111111111%
# Outliers:
# Index(['BEEF ROAST', 'CLAMS RAW', 'CLAMS CANNED'], dtype='object', name='Food_Item')

# %%
###### Visualization of Outliers ################
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
prcomp = PCA()
scores = prcomp.fit_transform(scaled_df)

print(np.cumsum(prcomp.explained_variance_ratio_))

obs = np.where(predictions == 1, "Inlier", "Outlier")
PCs = pd.DataFrame({'PC1':scores[:,0], 'PC2':scores[:,1],
                    'Class':obs})

sns.scatterplot(data=PCs, x='PC1',
                y='PC2', hue='Class')
for i in np.arange(0, df.shape[0] ):
    plt.text(scores[i,0], scores[i,1], 
             list(df.index)[i],fontsize=6)
plt.legend(loc='best')
plt.title("PCA")
plt.show()
# Out:
# [0.43926469 0.66844264 0.83798533 0.99967967 1.        ]
