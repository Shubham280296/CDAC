# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf

# %%
######### AirPassengers

# %%
airpass = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\AirPassengers.csv")
airpass.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
###### ADFuller for passengers

# %%
results = adfuller(airpass['Passengers'],maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.998969450186538
# Time Series is non-stationary

# %%
plot_acf(airpass['Passengers'],lags=30,alpha=None)
plt.show()

# %%
###### ADFuller for passengers on 1st order differencing

# %%
diff1_air = airpass['Passengers'].diff(1)
diff1_air.dropna(inplace=True)
results = adfuller(diff1_air,maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  8.674876853271811e-29
# Time series is stationary

# %%
plot_acf(diff1_air,lags=30,alpha=None)
plt.show()

# %%
############## Coal Consumption.

# %%
CoalCon = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\Coal Consumption.csv")
CoalCon.head()
# Out:
#       Month  Amount
# 0  1/1/1990   16.50
# 1  2/1/1990   15.17
# 2  3/1/1990   12.75
# 3  4/1/1990   12.31
# 4  5/1/1990    8.34

# %%
###### ADFuller for amount

# %%
results = adfuller(CoalCon['Amount'],maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.4015182663700355
# Time Series is non-stationary

# %%
plot_acf(CoalCon['Amount'],lags=30,alpha=None)
plt.show()

# %%
######### ADfuller on amount 1st order

# %%
diff1_coal =CoalCon['Amount'].diff(1)
diff1_coal.dropna(inplace=True)
results = adfuller(diff1_coal,maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  1.019436966018649e-27
# Time series is stationary

# %%
plot_acf(diff1_coal,lags=30,alpha=None)
plt.show()

# %%
############# FMAC-HPI_24420

# %%
FMAC = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\FMAC-HPI_24420.csv")
FMAC.head()
# Out:
#          Date  NSA Value   SA Value
# 0  31-01-1975  24.739893  24.687815
# 1  28-02-1975  25.266825  25.200482
# 2  31-03-1975  25.765667  25.633002
# 3  30-04-1975  26.212724  26.009987
# 4  31-05-1975  26.628081  26.350592

# %%
###### ADFuller for NSA

# %%
results = adfuller(FMAC['NSA Value'],maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.29693588433339957
# Time Series is non-stationary

# %%
plot_acf(FMAC['NSA Value'],lags=30,alpha=None)
plt.show()

# %%
###### ADFuller for SA

# %%
results = adfuller(FMAC['SA Value'],maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.6628914373822354
# Time Series is non-stationary

# %%
plot_acf(FMAC['SA Value'],lags=30,alpha=None)
plt.show()

# %%
######### ADfuller on NSA 1st order

# %%
diff1_NSA = FMAC['NSA Value'].diff(1)
diff1_NSA.dropna(inplace=True)
results = adfuller(diff1_NSA,maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.2981388157244667
# Time Series is non-stationary

# %%
plot_acf(diff1_NSA,lags=30,alpha=None)
plt.show()

# %%
######### ADfuller on NSA 2nd order differencing

# %%
diff2_NSA = FMAC['NSA Value'].diff(1).diff(1)
diff2_NSA.dropna(inplace=True)
results = adfuller(diff2_NSA,maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  5.442541314546984e-12
# Time series is stationary

# %%
plot_acf(diff2_NSA,lags=30,alpha=None)
plt.show()

# %%
######### ADfuller on SA 1st order

# %%
diff1_SA = FMAC['SA Value'].diff(1)
diff1_SA.dropna(inplace=True)
results = adfuller(diff1_SA,maxlag=10)
print("P-value = ", results[1])
if results[1]<0.05 : 
    print("Time series is stationary")
else :
    print("Time Series is non-stationary")
# Out:
# P-value =  0.02548894397330401
# Time series is stationary

# %%
plot_acf(diff1_SA,lags=30,alpha=None)
plt.show()
