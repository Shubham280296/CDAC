# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from pca import pca

# %%
iris = pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\iris.csv')

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaler.fit(iris.drop("Species",axis=1))
irisscaled = scaler.transform(iris.drop("Species",axis=1))

# %%
prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(irisscaled)
principalComponents.head()
# Out:
#        pca0      pca1      pca2      pca3
# 0 -2.264703  0.480027 -0.127706 -0.024168
# 1 -2.080961 -0.674134 -0.234609 -0.103007
# 2 -2.364229 -0.341908  0.044201 -0.028377
# 3 -2.299384 -0.597395  0.091290  0.065956
# 4 -2.389842  0.646835  0.015738  0.035923

# %%
print(np.cumsum(prcomp.explained_variance_))
print(np.cumsum(prcomp.explained_variance_ratio_))
print(np.cumsum(prcomp.explained_variance_ratio_*100))
print(np.cumsum(prcomp.explained_variance_ratio_*100)[1])
# Out:
# [2.93808505 3.85824995 4.00599178 4.02684564]
# [0.72962445 0.95813207 0.99482129 1.        ]
# [ 72.96244541  95.8132072   99.48212909 100.        ]
# 95.81320720000163

# %%
ys = np.cumsum(prcomp.explained_variance_ratio_*100)
xs = np.arange(1,5)
plt.plot(xs,ys)

# %%
principalComponents["Species"]=iris["Species"]
sns.scatterplot(x='pca0',y='pca1',data=principalComponents, hue='Species')
plt.show()

# %%
sns.pairplot(data=principalComponents,hue='Species')
plt.show()

# %%
principalComponents["Species"][1]
# Out:
# 'setosa'

# %%
model = pca()
results = model.fit_transform(irisscaled, col_labels=irisscaled.columns,row_labels =iris["Species"] )
model.biplot(label=True, legend=True)
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [4] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [4] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
# ...

# %%
######### milk

# %%
milk = pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\milk.csv',index_col=0)

# %%
milk.head()
# Out:
#            water  protein  fat  lactose   ash
# Animal
# HORSE       90.1      2.6  1.0      6.9  0.35
# ORANGUTAN   88.5      1.4  3.5      6.0  0.24
# MONKEY      88.4      2.2  2.7      6.4  0.18
# DONKEY      90.3      1.7  1.4      6.2  0.40
# HIPPO       90.4      0.6  4.5      4.4  0.10

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaler.fit(milk)
milkscaled = scaler.transform(milk)

# %%
prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(milkscaled)
principalComponents.head()
# Out:
#                pca0      pca1      pca2      pca3      pca4
# Animal
# HORSE     -2.435175 -0.231478  0.330150  0.307664 -0.048184
# ORANGUTAN -2.258736 -0.693148  0.029035 -0.081057  0.000532
# MONKEY    -2.335861 -0.663328  0.101257  0.247997 -0.010109
# DONKEY    -2.318677 -0.273815  0.109881 -0.092873  0.006769
# HIPPO     -2.060294 -1.019199 -0.762436 -0.510091 -0.029382

# %%
print(np.cumsum(prcomp.explained_variance_))
print(np.cumsum(prcomp.explained_variance_ratio_))
print(np.cumsum(prcomp.explained_variance_ratio_*100))
print(np.cumsum(prcomp.explained_variance_ratio_*100)[1])
# Out:
# [4.0404117  4.96478408 5.09907497 5.20176356 5.20833333]
# [0.77575905 0.95323854 0.97902239 0.9987386  1.        ]
# [ 77.57590469  95.32385438  97.90223934  99.87386037 100.        ]
# 95.32385437937

# %%
ys = np.cumsum(prcomp.explained_variance_ratio_*100)
xs = np.arange(1,6)
plt.plot(xs,ys)

# %%
model = pca()
results = model.fit_transform(milkscaled, col_labels=milkscaled.columns,row_labels =list(milkscaled.index) )
model.biplot(label=True, legend=True)
for i in np.arange(0,milkscaled.shape[0]):
    plt.text(principalComponents.values[i,0],principalComponents.values[i,1],list(milkscaled.index)[i])
plt.show()
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [5] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [5] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
