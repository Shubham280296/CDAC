# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from pca import pca

# %%
country = pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Unsupervised Learning on Country Data\Country-data.csv',index_col=0)
country
# Out:
#                      child_mort  exports  health  imports  income  inflation  \
# country
# Afghanistan                90.2     10.0    7.58     44.9    1610       9.44
# Albania                    16.6     28.0    6.55     48.6    9930       4.49
# Algeria                    27.3     38.4    4.17     31.4   12900      16.10
# Angola                    119.0     62.3    2.85     42.9    5900      22.40
# Antigua and Barbuda        10.3     45.5    6.03     58.9   19100       1.44
# ...                         ...      ...     ...      ...     ...        ...
# Vanuatu                    29.2     46.6    5.25     52.7    2950       2.62
# Venezuela                  17.1     28.5    4.91     17.6   16500      45.90
# Vietnam                    23.3     72.0    6.84     80.2    4490      12.10
# Yemen                      56.3     30.0    5.18     34.4    4480      23.60
# Zambia                     83.1     37.0    5.89     30.9    3280      14.00
#
#                      life_expec  total_fer   gdpp
# country
# Afghanistan                56.2       5.82    553
# Albania                    76.3       1.65   4090
# Algeria                    76.5       2.89   4460
# Angola                     60.1       6.16   3530
# Antigua and Barbuda        76.8       2.13  12200
# ...                         ...        ...    ...
# Vanuatu                    63.0       3.50   2970
# Venezuela                  75.4       2.47  13500
# Vietnam                    73.1       1.95   1310
# Yemen                      67.5       4.67   1310
# Zambia                     52.0       5.40   1460
#
# [167 rows x 9 columns]

# %%
scaler = StandardScaler().set_output(transform='pandas')
country_scaled=scaler.fit_transform(country)

# %%
prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(country_scaled)
principalComponents.head()
# Out:
#                          pca0      pca1      pca2      pca3      pca4  \
# country
# Afghanistan         -2.913025  0.095621 -0.718118  1.005255 -0.158310
# Albania              0.429911 -0.588156 -0.333486 -1.161059  0.174677
# Algeria             -0.285225 -0.455174  1.221505 -0.868115  0.156475
# Angola              -2.932423  1.695555  1.525044  0.839625 -0.273209
# Antigua and Barbuda  1.033576  0.136659 -0.225721 -0.847063 -0.193007
#
#                          pca5      pca6      pca7      pca8
# country
# Afghanistan         -0.254597  0.383000  0.415076 -0.014148
# Albania              0.084579  0.248919 -0.221042  0.173316
# Algeria             -0.401696 -0.087214 -0.184162  0.084037
# Angola              -0.547996 -0.440835 -0.355998 -0.091339
# Antigua and Barbuda -0.206919  0.241978 -0.023681  0.094270

# %%
print(np.cumsum(prcomp.explained_variance_))
print(np.cumsum(prcomp.explained_variance_ratio_))
print(np.cumsum(prcomp.explained_variance_ratio_*100))
print(np.cumsum(prcomp.explained_variance_ratio_*100)[6])
# Out:
# [4.16057017 5.71623182 6.89366563 7.89444287 8.55904153 8.78396952
#  8.89809162 8.986939   9.05421687]
# [0.4595174  0.63133365 0.76137624 0.87190786 0.94530998 0.97015232
#  0.98275663 0.99256944 1.        ]
# [ 45.95173979  63.13336544  76.13762433  87.19078614  94.53099756
#   97.01523224  98.27566264  99.25694438 100.        ]
# 98.27566263898788

# %%
ys = np.cumsum(prcomp.explained_variance_ratio_*100)
xs = np.arange(1,10)
plt.plot(xs,ys)

# %%
model = pca()
results = model.fit_transform(country_scaled, col_labels=country_scaled.columns,row_labels =list(country_scaled.index) )
model.biplot(label=True, legend=True)
for i in np.arange(0,country_scaled.shape[0]):
    plt.text(principalComponents.values[i,0],principalComponents.values[i,1],list(country_scaled.index)[i])
plt.show()
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [9] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [6] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [9] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[6]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
