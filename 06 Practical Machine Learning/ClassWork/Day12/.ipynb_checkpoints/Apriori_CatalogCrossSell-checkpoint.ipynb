# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\Cosmetics.csv",index_col=0)
df.head()
# Out:
#          Bag  Blush  Nail Polish  Brushes  Concealer  Eyebrow Pencils  \
# Trans.
# 1          0      1            1        1          1                0
# 2          0      0            1        0          1                0
# 3          0      1            0        0          1                1
# 4          0      0            1        1          1                0
# 5          0      1            0        0          1                0
#
#          Bronzer  Lip liner  Mascara  Eye shadow  Foundation  Lip Gloss  \
# Trans.
# 1              1          1        1           0           0          0
# 2              1          1        0           0           1          1
# 3              1          1        1           1           1          1
# 4              1          0        0           0           1          0
# 5              1          1        1           1           0          1
#
#          Lipstick  Eyeliner
# Trans.
# 1               0         1
# 2               0         0
# 3               1         0
# 4               0         1
# 5               1         0

# %%
df = df.astype(bool)
itemsets = apriori(df, min_support = 0.2,use_colnames=True)

rules = association_rules(itemsets, metric= 'confidence', min_threshold = 0.6)

print(rules[['antecedents','consequents','support','confidence','lift']])
# Out:
#     antecedents   consequents  support  confidence      lift
# 0       (Blush)   (Concealer)    0.220    0.606061  1.371178
# 1    (Eyeliner)   (Concealer)    0.297    0.649891  1.470341
# 2   (Concealer)    (Eyeliner)    0.297    0.671946  1.470341
# 3     (Mascara)  (Eye shadow)    0.321    0.899160  2.359999
# 4  (Eye shadow)     (Mascara)    0.321    0.842520  2.359999
# 5  (Foundation)   (Lip Gloss)    0.356    0.664179  1.355468
# 6   (Lip Gloss)  (Foundation)    0.356    0.726531  1.355468

# %%
rules.sort_values(by = 'lift', ascending=False).head(6)
# Out:
#     antecedents   consequents  antecedent support  consequent support  \
# 4  (Eye shadow)     (Mascara)               0.381               0.357
# 3     (Mascara)  (Eye shadow)               0.357               0.381
# 1    (Eyeliner)   (Concealer)               0.457               0.442
# 2   (Concealer)    (Eyeliner)               0.442               0.457
# 0       (Blush)   (Concealer)               0.363               0.442
# 5  (Foundation)   (Lip Gloss)               0.536               0.490
#
#    support  confidence      lift  leverage  conviction  zhangs_metric
# 4    0.321    0.842520  2.359999  0.184983    4.083050       0.930971
# 3    0.321    0.899160  2.359999  0.184983    6.138417       0.896222
# 1    0.297    0.649891  1.470341  0.095006    1.593787       0.589108
# 2    0.297    0.671946  1.470341  0.095006    1.655214       0.573272
# 0    0.220    0.606061  1.371178  0.059554    1.416462       0.424961
# 5    0.356    0.664179  1.355468  0.093360    1.518667       0.565188

# %%
rules_df = rules.sort_values(by = ['lift','confidence'], ascending=False)
relv_rules = rules_df[rules_df['lift']>1]
relv_rules
# Out:
#     antecedents   consequents  antecedent support  consequent support  \
# 4  (Eye shadow)     (Mascara)               0.381               0.357
# 3     (Mascara)  (Eye shadow)               0.357               0.381
# 2   (Concealer)    (Eyeliner)               0.442               0.457
# 1    (Eyeliner)   (Concealer)               0.457               0.442
# 0       (Blush)   (Concealer)               0.363               0.442
# 5  (Foundation)   (Lip Gloss)               0.536               0.490
# 6   (Lip Gloss)  (Foundation)               0.490               0.536
#
#    support  confidence      lift  leverage  conviction  zhangs_metric
# 4    0.321    0.842520  2.359999  0.184983    4.083050       0.930971
# 3    0.321    0.899160  2.359999  0.184983    6.138417       0.896222
# 2    0.297    0.671946  1.470341  0.095006    1.655214       0.573272
# 1    0.297    0.649891  1.470341  0.095006    1.593787       0.589108
# 0    0.220    0.606061  1.371178  0.059554    1.416462       0.424961
# 5    0.356    0.664179  1.355468  0.093360    1.518667       0.565188
# 6    0.356    0.726531  1.355468  0.093360    1.696716       0.514210
