# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\monthly-beer-production-in-austr.csv",index_col=0)
df.index = pd.to_datetime(df.index).to_period("M")

# %%
df.plot()
plt.title("Monthly beer prod")
plt.xlabel("Months")
plt.show()

# %%
downsampled = df.resample('Q').sum()
downsampled.index.rename('Quarter',inplace=True)
downsampled.plot()
plt.title("Quarterly beer prod")
plt.xlabel("Quarters")
plt.show()
