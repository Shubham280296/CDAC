# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
kyp = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Cases\Kyphosis\Kyphosis.csv")
le = LabelEncoder()
y = le.fit_transform(kyp["Kyphosis"])
X = kyp.drop('Kyphosis',axis=1)

lr = LogisticRegression(solver ="saga")
kfold = StratifiedKFold(n_splits = 5,shuffle=True,random_state= 24)
params= {"penalty":["elasticnet","l1","l2",None],"C": np.linspace(0.001,10,5),"l1_ratio":np.linspace(0.001,1,4)}

gcv = GridSearchCV(lr,param_grid=params,cv=kfold, scoring="neg_log_loss")# default scoring r2

gcv.fit(X,y)

print(gcv.best_params_)
print(gcv.best_score_)
pd.DataFrame(gcv.cv_results_)
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
# ...

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# -0.41678681332315665
# {'C': 10.0, 'l1_ratio': 0.001, 'penalty': 'l2'}

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Cases\Bankruptcy\Bankruptcy.csv")

X = df.iloc[:,2:]
y = df.iloc[:,1]

# %%
lr = LogisticRegression(solver ="saga",random_state=24)
kfold = StratifiedKFold(n_splits = 5,shuffle=True,random_state= 24)
params= {"penalty":["elasticnet","l1","l2",None],"C": np.linspace(0.001,10,5),"l1_ratio":np.linspace(0.001,1,4)}

gcv = GridSearchCV(lr,param_grid=params,cv=kfold, scoring="neg_log_loss")# default scoring r2

gcv.fit(X,y)
pd.DataFrame(gcv.cv_results_)
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
# ...

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# -0.6320604640519241
# {'C': 0.001, 'l1_ratio': 0.001, 'penalty': None}

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Cases\Glass Identification\Glass.csv")
le = LabelEncoder()
X = df.iloc[:,:-1]
y = le.fit_transform(df.iloc[:,-1])

# %%
lr = LogisticRegression(solver ="saga",random_state=24)
kfold = StratifiedKFold(n_splits = 5,shuffle=True,random_state= 24)
params= {"penalty":["elasticnet","l1","l2",None],"C": np.linspace(0.001,10,5),"l1_ratio":np.linspace(0.001,1,4),"multi_class":["ovr","multinomial"]}

gcv = GridSearchCV(lr,param_grid=params,cv=kfold, scoring="neg_log_loss")# default scoring r2

gcv.fit(X,y)
pd.DataFrame(gcv.cv_results_)
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
# ...

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# -1.098224924028305
# {'C': 0.001, 'l1_ratio': 0.001, 'multi_class': 'multinomial', 'penalty': None}

# %%
pd.DataFrame(gcv.cv_results_).isna().sum()
# Out:
# mean_fit_time         0
# std_fit_time          0
# mean_score_time       0
# std_score_time        0
# param_C               0
# param_l1_ratio        0
# param_multi_class     0
# param_penalty        40
# params                0
# split0_test_score     0
# split1_test_score     0
# split2_test_score     0
# split3_test_score     0
# split4_test_score     0
# mean_test_score       0
# std_test_score        0
# rank_test_score       0
# dtype: int64
