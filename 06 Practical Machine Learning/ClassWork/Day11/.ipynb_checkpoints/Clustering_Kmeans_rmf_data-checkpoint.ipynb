# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import warning
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 10
#       8 from sklearn.metrics import silhouette_score
#       9 from sklearn.decomposition import PCA
# ---> 10 import warning
#
# ModuleNotFoundError: No module named 'warning'

# %%
#### milk

# %%
milk = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\milk.csv",index_col=0)
milk.head()
# Out:
#            water  protein  fat  lactose   ash
# Animal
# HORSE       90.1      2.6  1.0      6.9  0.35
# ORANGUTAN   88.5      1.4  3.5      6.0  0.24
# MONKEY      88.4      2.2  2.7      6.4  0.18
# DONKEY      90.3      1.7  1.4      6.2  0.40
# HIPPO       90.4      0.6  4.5      4.4  0.10

# %%
scaler = StandardScaler().set_output(transform='pandas')
milk_scaled = scaler.fit_transform(milk)

Ks = np.arange(2,6)
scores = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(milk_scaled)
    scores.append(silhouette_score(milk_scaled, clust.labels_))

i_max = np.argmax(scores)
print("Best no. of clusters:", Ks[i_max])
print("Best Score:", scores[i_max])
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
clust = KMeans(n_clusters= Ks[i_max],random_state=24,init='random')
clust.fit(milk_scaled)

prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(milk_scaled)
print(np.cumsum(prcomp.explained_variance_ratio_*100))

principalComponents["Clust"]=clust.labels_.astype(str)
sns.scatterplot(x='pca0',y='pca1',data=principalComponents, hue='Clust')
for i in np.arange(0,milk_scaled.shape[0]):
    plt.text(principalComponents.values[i,0],principalComponents.values[i,1],list(milk_scaled.index)[i])
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [ 77.57590469  95.32385438  97.90223934  99.87386037 100.        ]

# %%
clust_milk = milk.copy()
clust_milk['Clust'] = clust.labels_.astype(str)

clust_milk.groupby('Clust').mean()
# Out:
#            water    protein        fat   lactose       ash
# Clust
# 0      85.158824   4.235294   4.964706  5.147059  0.635294
# 1      69.266667  10.500000  16.066667  2.483333  1.566667
# 2      45.650000  10.150000  38.450000  0.450000  0.690000

# %%
Ks = np.arange(2,25)
inertia = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(milk_scaled)
    inertia.append(clust.inertia_)
plt.plot(Ks,inertia,marker='*')
plt.title("WSS vs number of clusters(Scree plot)")
plt.xlabel("No of clusters")
plt.ylabel("WSS");
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
####### nutrient

# %%
nutrient = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\nutrient.csv",index_col=0)
nutrient.head()
# Out:
#               energy  protein  fat  calcium  iron
# Food_Item
# BEEF BRAISED     340       20   28        9   2.6
# HAMBURGER        245       21   17        9   2.7
# BEEF ROAST       420       15   39        7   2.0
# BEEF STEAK       375       19   32        9   2.6
# BEEF CANNED      180       22   10       17   3.7

# %%
scaler = StandardScaler().set_output(transform='pandas')
nutrient_scaled = scaler.fit_transform(nutrient)

Ks = np.arange(2,13)
scores = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(nutrient_scaled)
    scores.append(silhouette_score(nutrient_scaled, clust.labels_))

i_max = np.argmax(scores)
print("Best no. of clusters:", Ks[i_max])
print("Best Score:", scores[i_max])
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
clust = KMeans(n_clusters= Ks[i_max],random_state=24,init='random')
clust.fit(nutrient_scaled)

prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(nutrient_scaled)
print(np.cumsum(prcomp.explained_variance_ratio_*100))

principalComponents["Clust"]=clust.labels_.astype(str)
sns.scatterplot(x='pca0',y='pca1',data=principalComponents, hue='Clust')
for i in np.arange(0,nutrient_scaled.shape[0]):
    plt.text(principalComponents.values[i,0],principalComponents.values[i,1],list(nutrient_scaled.index)[i])
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [ 43.92646868  66.84426409  83.79853301  99.96796701 100.        ]

# %%
clust_nutrient = nutrient.copy()
clust_nutrient['Clust'] = clust.labels_.astype(str)

clust_nutrient.groupby('Clust').mean()
# Out:
#            energy    protein        fat     calcium      iron
# Clust
# 0      341.875000  18.750000  28.875000    8.750000  2.437500
# 1       57.500000   9.000000   1.000000   78.000000  5.700000
# 2      151.666667  18.333333   7.666667  227.666667  1.666667
# 3      163.928571  20.714286   7.714286   19.857143  2.028571

# %%
Ks = np.arange(2,25)
inertia = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(nutrient_scaled)
    inertia.append(clust.inertia_)
plt.plot(Ks,inertia,marker='*')
plt.title("WSS vs number of clusters(Scree plot)")
plt.xlabel("No of clusters")
plt.ylabel("WSS");
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
############# protein

# %%
protein = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Datasets\Protein.csv",index_col=0)
protein.head()
# Out:
#                 RedMeat  WhiteMeat  Eggs  Milk  Fish  Cereals  Starch  Nuts  \
# Country
# Albania            10.1        1.4   0.5   8.9   0.2     42.3     0.6   5.5
# Austria             8.9       14.0   4.3  19.9   2.1     28.0     3.6   1.3
# Belgium            13.5        9.3   4.1  17.5   4.5     26.6     5.7   2.1
# Bulgaria            7.8        6.0   1.6   8.3   1.2     56.7     1.1   3.7
# Czechoslovakia      9.7       11.4   2.8  12.5   2.0     34.3     5.0   1.1
#
#                 Fr&Veg
# Country
# Albania            1.7
# Austria            4.3
# Belgium            4.0
# Bulgaria           4.2
# Czechoslovakia     4.0

# %%
scaler = StandardScaler().set_output(transform='pandas')
protein_scaled = scaler.fit_transform(protein)

Ks = np.arange(2,13)
scores = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(protein_scaled)
    scores.append(silhouette_score(protein_scaled, clust.labels_))

i_max = np.argmax(scores)
print("Best no. of clusters:", Ks[i_max])
print("Best Score:", scores[i_max])
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
clust = KMeans(n_clusters= Ks[i_max],random_state=24,init='random')
clust.fit(protein_scaled)

prcomp = PCA().set_output(transform='pandas')
principalComponents = prcomp.fit_transform(protein_scaled)
print(np.cumsum(prcomp.explained_variance_ratio_*100))

principalComponents["Clust"]=clust.labels_.astype(str)
sns.scatterplot(x='pca0',y='pca1',data=principalComponents, hue='Clust')
for i in np.arange(0,protein_scaled.shape[0]):
    plt.text(principalComponents.values[i,0],principalComponents.values[i,1],list(protein_scaled.index)[i])
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [ 44.51597304  62.68263357  75.2150725   85.82244989  90.97620984
#   94.58877619  97.60662435  98.89875662 100.        ]

# %%
clust_protein = protein.copy()
clust_protein['Clust'] = clust.labels_.astype(str)

clust_protein.groupby('Clust').mean()
# Out:
#          RedMeat  WhiteMeat      Eggs       Milk      Fish    Cereals  \
# Clust
# 0       8.125000   3.800000  2.475000  11.200000  7.625000  33.675000
# 1      11.340000   9.766667  3.580000  21.260000  4.686667  25.553333
# 2       7.183333   5.950000  1.633333  10.683333  1.050000  48.033333
#
#          Starch      Nuts    Fr&Veg
# Clust
# 0      3.975000  5.675000  7.075000
# 1      4.853333  1.673333  3.740000
# 2      3.033333  4.833333  3.166667

# %%
Ks = np.arange(2,25)
inertia = []
for i in Ks:
    clust = KMeans(n_clusters=i,random_state=24,init='random')
    clust.fit(protein_scaled)
    inertia.append(clust.inertia_)
plt.plot(Ks,inertia,marker='*')
plt.title("WSS vs number of clusters(Scree plot)")
plt.xlabel("No of clusters")
plt.ylabel("WSS");
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...
