# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder, StandardScaler,MinMaxScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, log_loss
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\ClassWork\Cases\Glass Identification\Glass.csv")
le = LabelEncoder()
X = df.iloc[:,:-1]
y = le.fit_transform(df.iloc[:,-1])

# %%
##### ovr/ovo - scaling data and using predict.proba enable probability in parameters for SVC gridsearch

# %%
svm = SVC(C =  0.1,kernel = "linear",probability =True, random_state=24)
scl_mm = MinMaxScaler()
scl_std = StandardScaler()
pipe = Pipeline([("Scl",None),("SVM",svm)])
params = {"SVM__C":np.linspace(0.001,5,20),"Scl":[scl_mm,scl_std,None],"SVM__decision_function_shape":["ovr","ovo"]}
kfold = StratifiedKFold(n_splits =5,shuffle = True, random_state = 24)
gcv = GridSearchCV(pipe,param_grid = params,cv=kfold, scoring="neg_log_loss")
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'SVM__C': 0.7903157894736842, 'SVM__decision_function_shape': 'ovr', 'Scl': None}
# -0.931260449901816

# %%
############ ovr/ovo- polynomial kernel scaling data and using predict.proba enable probability in parameters for SVC gridsearch

# %%
svm = SVC(C =  0.1,kernel = "poly",probability =True, random_state=24)
scl_mm = MinMaxScaler()
scl_std = StandardScaler()
pipe = Pipeline([("Scl",None),("SVM",svm)])

params = {"SVM__C":np.linspace(0.001,5,20),"Scl":[scl_mm,scl_std,None],"SVM__degree":[2,3],"SVM__coef0":np.linspace(0,3,5),"SVM__decision_function_shape":["ovr","ovo"]}
kfold = StratifiedKFold(n_splits =5,shuffle = True, random_state = 24)
gcv = GridSearchCV(pipe,param_grid = params,cv=kfold, scoring="neg_log_loss")
gcv.fit(X,y)

print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 1200 candidates, totalling 6000 fits
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=StandardScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__coef0=0.0, SVM__decision_function_shape=ovr, SVM__degree=2, Scl=StandardScaler(); total time=   0.0s
# ...

# %%
#### ovr/ovo - radial kernel scaling data and using predict.proba enable probability in parameters for SVC gridsearch

# %%
svm = SVC(C =  0.1,kernel = "rbf",probability =True, random_state=24)
scl_mm = MinMaxScaler()
scl_std = StandardScaler()
pipe = Pipeline([("Scl",None),("SVM",svm)])
params = {"SVM__C":np.linspace(0.001,5,20),"Scl":[scl_mm,scl_std,None],"SVM__gamma":np.linspace(0.001,5,5),"SVM__decision_function_shape":["ovr","ovo"]}
kfold = StratifiedKFold(n_splits =5,shuffle = True, random_state = 24)
gcv = GridSearchCV(pipe,param_grid = params,cv=kfold, scoring="neg_log_loss")
gcv.fit(X,y)

print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=MinMaxScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=StandardScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=StandardScaler(); total time=   0.0s
# [CV] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001, Scl=StandardScaler(); total time=   0.0s
# ...

# %%
#### ovr/ovo - sigmoid kernel scaling data and using predict.proba enable probability in parameters for SVC gridsearch

# %%
svm = SVC(C =  0.1,kernel = "sigmoid",probability =True, random_state=24)
scl_mm = MinMaxScaler()
scl_std = StandardScaler()
pipe = Pipeline([("Scl",None),("SVM",svm)])
params = {"SVM__C":np.linspace(0.001,5,20),"Scl":[scl_mm,scl_std,None],"SVM__gamma":np.linspace(0.001,5,5),"SVM__coef0":np.linspace(0,3,5),"SVM__decision_function_shape":["ovr","ovo"]}
kfold = StratifiedKFold(n_splits =5,shuffle = True, random_state = 24)
gcv = GridSearchCV(pipe,param_grid = params,cv=kfold, scoring="neg_log_loss")
gcv.fit(X,y)

print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'SVM__C': 1.5796315789473683, 'SVM__coef0': 0.0, 'SVM__decision_function_shape': 'ovr', 'SVM__gamma': 0.001, 'Scl': StandardScaler()}
# -1.0358929844317548
