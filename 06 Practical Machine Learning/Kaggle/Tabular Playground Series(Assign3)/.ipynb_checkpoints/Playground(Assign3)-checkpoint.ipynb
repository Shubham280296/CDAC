# %% [raw]
# 3. Consider the dataset at the link https://www.kaggle.com/competitions/tabular-playground-series-mar-2022  Try the following models by method of log(response):
# Linear Regression
# ElasticNet Regression
# XGBoost
# CatBoost
# LightGBM
#
# Mention leaderboard scores for each of the five.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, ElasticNet
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV, KFold

# %%
train = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Tabular Playground Series(Assign3)\train.csv",index_col=0,parse_dates=['time'])
test = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Tabular Playground Series(Assign3)\test.csv",index_col=0,parse_dates=['time'])

# %%
train['day'] = train['time'].dt.day
train['month'] = train['time'].dt.month
train['weekday'] = train['time'].dt.weekday
train['hour'] = train['time'].dt.hour
train['min'] = train['time'].dt.minute

test['day'] = test['time'].dt.day
test['month'] = test['time'].dt.month
test['weekday'] = test['time'].dt.weekday
test['hour'] = test['time'].dt.hour
test['min'] = test['time'].dt.minute

# %%
train = train.drop('time', axis=1)
test = test.drop('time', axis=1)

train_dum = pd.get_dummies(train,drop_first=True)
test_dum = pd.get_dummies(test,drop_first=True)

X_train = train_dum.drop("congestion",axis=1)
y_train = np.log1p(train_dum["congestion"])

# %%
##### LogisticRegression #######

# %%
lr = LinearRegression()
kfold = KFold(n_splits=5,shuffle=True,random_state=24)
param = {}
gcv_lr = GridSearchCV(lr,cv = kfold, param_grid=param,scoring="neg_mean_absolute_error")
gcv_lr.fit(X_train,y_train)
print(gcv_lr.best_score_)
# Out:
# -0.276355758390261

# %%
y_pred = np.expm1(gcv_lr.predict(test_dum))
submit = pd.DataFrame({"row_id":test.index,"congestion":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Tabular Playground Series(Assign3)\linear.csv",index=False)

# %%
########### Random Forest ##########

# %%
elastic = ElasticNet(random_state=24)
kfold = KFold(n_splits=5,shuffle=True,random_state=24)
param = {"max_depth": [None,3,4,5]}
gcv_elastic = GridSearchCV(elastic,cv = kfold, param_grid=param,scoring="neg_mean_squared_log_error")
gcv_elastic.fit(X_train,y_train)
print(gcv_elastic.best_score_)
print(gcv_elastic.best_params_)
# Out:
# -0.0238085564820649
# {'max_depth': None}

# %%
y_pred = np.expm1(gcv_elastic.predict(test_dum))
submit = pd.DataFrame({"row_id":test.index,"FloodProbability":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Abalone(assign1)\RandomForest.csv",index=False)

# %%
########## X G Boost #################

# %%
xgb = XGBRegressor(random_state=24)
kfold = KFold(n_splits=5,shuffle=True,random_state=24)
param = {"learning_rate":np.linspace(0.001,0.9,10),"max_depth":[None,3,4],"n_estimators":[25,50,100]}
gcv = GridSearchCV(xgb,cv = kfold, param_grid=param,scoring="neg_mean_squared_log_error")
gcv.fit(X_train,y_train)
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 350, in _score
# ...

# %%
y_pred  = gcv.predict(test)
submit = pd.DataFrame({"id":test.index,"FloodProbability":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Abalone(assign1)\xgb.csv",index=False)

# %%
###### LGBMRegressor ############

# %%
lgbm = LGBMRegressor(random_state=24)
kfold = KFold(n_splits=5,shuffle=True,random_state=24)
params = {"learning_rate":np.linspace(0.001,0.9,10),"max_depth":[None,2,3,4],"n_estimators":[25,50,100]}
gcv = GridSearchCV(lgbm,cv = kfold, param_grid=param,scoring="neg_mean_squared_log_error")
gcv.fit(X_train,y_train)
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1330
# [LightGBM] [Info] Number of data points in the train set: 72492, number of used features: 9
# [LightGBM] [Info] Start training from score 9.696877
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000838 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1331
# [LightGBM] [Info] Number of data points in the train set: 72492, number of used features: 9
# [LightGBM] [Info] Start training from score 9.704354
# ...

# %%
y_pred  = gcv.predict(test)
submit = pd.DataFrame({"id":test.index,"FloodProbability":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Abalone(assign1)\lgbm.csv",index=False)

# %%
############ Stacking ###########

# %%
rf = RandomForestRegressor(random_state=24)
xgb = XGBRegressor(random_state=24)
lgbm = LGBMRegressor(random_state=24)
cat =  CatBoostRegressor(random_state=24)
stack1 = StackingRegressor([('Tree',rf),('XGB',xgb),("LGBM",lgbm)],final_estimator=cat,passthrough=True)

stack1.fit(X_train,y_train)

y_pred  = stack1.predict(test)
submit = pd.DataFrame({"id":test.index,"FloodProbability":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Abalone(assign1)\stack1.csv",index=False)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001216 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1335
# [LightGBM] [Info] Number of data points in the train set: 90615, number of used features: 9
# [LightGBM] [Info] Start training from score 9.696794
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1330
# [LightGBM] [Info] Number of data points in the train set: 72492, number of used features: 9
# [LightGBM] [Info] Start training from score 9.705223
# ...

# %%
rf = RandomForestRegressor(random_state=24)
xgb = XGBRegressor(random_state=24)
lgbm = LGBMRegressor(random_state=24)
cat =  CatBoostRegressor(random_state=24)
stack2 = StackingRegressor([('Tree',rf),('XGB',xgb),("CAT",cat)],final_estimator=lgbm,passthrough=True)

kfold = KFold(n_splits=5,shuffle=True,random_state=24)
params = {"final_estimator__learning_rate":np.linspace(0.001,0.9,5),"final_estimator__max_depth":[None,3,4],
          "final_estimator__n_estimators":[25,50,100]}
gcv = GridSearchCV(stack2,cv=kfold, param_grid=params,scoring="neg_mean_squared_log_error")

gcv.fit(X_train,y_train)

y_pred  = gcv.predict(test)
submit = pd.DataFrame({"id":test.index,"FloodProbability":y_pred})
submit.to_csv(r"C:\Users\Administrator.DAI-PC2\Downloads\Shubham\Practical Machine Learning\Kaggle\Abalone(assign1)\stack2.csv",index=False)
# Out:
# Learning rate set to 0.080557
# 0:	learn: 3.0510904	total: 158ms	remaining: 2m 37s
# 1:	learn: 2.9329261	total: 173ms	remaining: 1m 26s
# 2:	learn: 2.8299956	total: 184ms	remaining: 1m 1s
# 3:	learn: 2.7363028	total: 191ms	remaining: 47.6s
# 4:	learn: 2.6537422	total: 198ms	remaining: 39.4s
# 5:	learn: 2.5784834	total: 206ms	remaining: 34.1s
# 6:	learn: 2.5123154	total: 213ms	remaining: 30.2s
# 7:	learn: 2.4569857	total: 221ms	remaining: 27.4s
# 8:	learn: 2.4034171	total: 228ms	remaining: 25.1s
# 9:	learn: 2.3578660	total: 236ms	remaining: 23.3s
# 10:	learn: 2.3152599	total: 243ms	remaining: 21.8s
# 11:	learn: 2.2796654	total: 250ms	remaining: 20.6s
# 12:	learn: 2.2459416	total: 257ms	remaining: 19.5s
# 13:	learn: 2.2161975	total: 265ms	remaining: 18.6s
# 14:	learn: 2.1906414	total: 272ms	remaining: 17.9s
# 15:	learn: 2.1665035	total: 279ms	remaining: 17.2s
# 16:	learn: 2.1440721	total: 286ms	remaining: 16.5s
# 17:	learn: 2.1239809	total: 292ms	remaining: 15.9s
# ...
